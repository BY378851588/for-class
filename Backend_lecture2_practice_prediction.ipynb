# %%
import pandas as pd
import pickle

# %%
data={'MedInc':[4.5,9,6,6.5,11.6],
      'HouseAge':[5,8,15,21,30],
      'AveRooms':[5,8,6.8,7.6,11.7],
      'AveBedrms':[3,4,4,3.5,6],
      'Population':[5000,6000,8000,600,9500],
      'AveOccup':[2,5,7,11,4],
       'Latitude':[33.4,35.5,33.8,39.4,40.1],
       'Longitude':[-120.1,-119.2,-115.33, -118,-114]}

# %%
unknown_df=pd.DataFrame(data)

# %%
unknown_df
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0     4.5         5       5.0        3.0        5000         2      33.4
# 1     9.0         8       8.0        4.0        6000         5      35.5
# 2     6.0        15       6.8        4.0        8000         7      33.8
# 3     6.5        21       7.6        3.5         600        11      39.4
# 4    11.6        30      11.7        6.0        9500         4      40.1
#
#    Longitude
# 0    -120.10
# 1    -119.20
# 2    -115.33
# 3    -118.00
# 4    -114.00

# %%
model=pickle.load(open('rf_model_class_2_nn.pkl','rb'))

# %%
model.predict(unknown_df)
# Out:
# array([3.3942311, 4.2702252, 1.9904801, 2.20521  , 3.1078211])
